# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 39.0 MB/s eta 0:00:00
# ...

# %%
import torch

# Check if CUDA is available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

# %%
# Install RAPIDS cuML for GPU-accelerated ML (may require Colab Pro for full compatibility)
# !pip install cuml-cu11 --extra-index-url=https://pypi.nvidia.com

# %%
import cudf
import cuml
from cuml.cluster import KMeans
import numpy as np

# Example data
X = np.random.rand(100, 2).astype(np.float32)

# Convert to cuDF DataFrame for GPU acceleration
X_cudf = cudf.DataFrame.from_records(X)

# Apply KMeans clustering
kmeans = KMeans(n_clusters=3)
kmeans.fit(X_cudf)

print("Cluster centers (on GPU):")
print(kmeans.cluster_centers_)

# %%
from ultralytics import YOLO
model = YOLO('/content/yolov8n.pt')
model.to(device)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 175MB/s]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/My\ Drive/ /content/YOLOv8

# %%
# !unzip "/content/gdrive/MyDrive/archive (2).zip" -d /content/YOLOv8/
# Out:
# Archive:  /content/gdrive/MyDrive/archive (2).zip
#   inflating: /content/YOLOv8/aquarium_pretrain/README.dataset.txt
#   inflating: /content/YOLOv8/aquarium_pretrain/README.roboflow.txt
#   inflating: /content/YOLOv8/aquarium_pretrain/data.yaml
#   inflating: /content/YOLOv8/aquarium_pretrain/test/images/IMG_2289_jpeg_jpg.rf.fe2a7a149e7b11f2313f5a7b30386e85.jpg
#   inflating: /content/YOLOv8/aquarium_pretrain/test/images/IMG_2301_jpeg_jpg.rf.2c19ae5efbd1f8611b5578125f001695.jpg
#   inflating: /content/YOLOv8/aquarium_pretrain/test/images/IMG_2319_jpeg_jpg.rf.6e20bf97d17b74a8948aa48776c40454.jpg
#   inflating: /content/YOLOv8/aquarium_pretrain/test/images/IMG_2347_jpeg_jpg.rf.7c71ac4b9301eb358cd4a832844dedcb.jpg
#   inflating: /content/YOLOv8/aquarium_pretrain/test/images/IMG_2354_jpeg_jpg.rf.396e872c7fb0a95e911806986995ee7a.jpg
#   inflating: /content/YOLOv8/aquarium_pretrain/test/images/IMG_2371_jpeg_jpg.rf.54505f60b6706da151c164188c305849.jpg
# ...

# %%
import os

# Define the directory path
directory_path = '/content/gdrive/MyDrive/aquarium_pretrain/valid/images'
c=0
# Iterate through files in the directory
for filename in os.listdir(directory_path):
  c+=1
print(c)
# Out:
# 127

# %%
import os

# Define the directory path
directory_path = '/content/gdrive/MyDrive/aquarium_pretrain/valid/labels'
c=0
# Iterate through files in the directory
for filename in os.listdir(directory_path):
  c+=1
print(c)
# Out:
# 127

# %%
results = model.train(data="/content/gdrive/MyDrive/aquarium_pretrain/data.yaml", epochs=50, workers=1, batch=8,imgsz=640)
# Out:
# Ultralytics 8.3.9 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model.train(data='/content/gdrive/MyDrive/aquarium_pretrain/data.yaml',
                      epochs=50,
                      batch=8,
                      imgsz=640,
                      save=True,
                      save_period=1,
                      project='ML',
                      name='Under Water Object')
# Out:
# Ultralytics 8.3.9 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model.save('/content/gdrive/MyDrive/yolov8_trained_model.pt')

# %%
import shutil
import os

# Define the source and destination paths
source = '/content/runs'
destination = '/content/gdrive/MyDrive/Project/ML/Underwater/runs'

# Create the destination directory if it doesn't exist
os.makedirs(os.path.dirname(destination), exist_ok=True)

# Copy the folder
shutil.copytree(source, destination)

print("Folder copied successfully!")
# Out:
# Folder copied successfully!

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load and display the confusion matrix
confusion_matrix_path = '/content/gdrive/MyDrive/Project/ML/Underwater/runs/detect/train/confusion_matrix.png'

# Open and display the confusion matrix image
img = Image.open(confusion_matrix_path)
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.title("Confusion Matrix")
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load and display the confusion matrix
confusion_matrix_path = '/content/gdrive/MyDrive/Project/ML/Underwater/runs/detect/train/F1_curve.png'

# Open and display the confusion matrix image
img = Image.open(confusion_matrix_path)
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.title("F1-Confidence Curve")
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load and display the confusion matrix
confusion_matrix_path = '/content/gdrive/MyDrive/Project/ML/Underwater/runs/detect/train/PR_curve.png'

# Open and display the confusion matrix image
img = Image.open(confusion_matrix_path)
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.title("Precision-Recall Curve ")
plt.show()
